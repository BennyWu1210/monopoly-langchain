# %% [markdown]
# ## Monopoly Game Agent (v3)

# %% [markdown]
# The following notebook creates agents to automatically play Monopoly. You can
# specify the behaviour of these agents in two ways:
# - How the agents decide whether to buy a property
# - How the agents decide whether to build a house/hotel on a property
#
# At present, more extensive decision-making features (like trading or mortgaging) are not included. However, these could be added in future versions.

# %% [markdown]
# ### Project Setup (Do not edit)
#
# Install dependencies

# %%
# %pip install -r requirements.txt
# Out:
# Requirement already satisfied: langchain-community>=0.3.0 in ./venv/lib/python3.12/site-packages (from -r requirements.txt (line 1)) (0.3.16)
# Requirement already satisfied: langchain-chroma>=0.1.0 in ./venv/lib/python3.12/site-packages (from -r requirements.txt (line 2)) (0.2.1)
# Requirement already satisfied: langchain-openai>=0.2.0 in ./venv/lib/python3.12/site-packages (from -r requirements.txt (line 3)) (0.3.3)
# Requirement already satisfied: langchain>=0.3.0 in ./venv/lib/python3.12/site-packages (from -r requirements.txt (line 4)) (0.3.16)
# Requirement already satisfied: pydantic>=2.0.0 in ./venv/lib/python3.12/site-packages (from -r requirements.txt (line 5)) (2.10.6)
# Requirement already satisfied: PyYAML>=5.3 in ./venv/lib/python3.12/site-packages (from langchain-community>=0.3.0->-r requirements.txt (line 1)) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in ./venv/lib/python3.12/site-packages (from langchain-community>=0.3.0->-r requirements.txt (line 1)) (2.0.37)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in ./venv/lib/python3.12/site-packages (from langchain-community>=0.3.0->-r requirements.txt (line 1)) (3.11.11)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in ./venv/lib/python3.12/site-packages (from langchain-community>=0.3.0->-r requirements.txt (line 1)) (0.6.7)
# Requirement already satisfied: httpx-sse<0.5.0,>=0.4.0 in ./venv/lib/python3.12/site-packages (from langchain-community>=0.3.0->-r requirements.txt (line 1)) (0.4.0)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.32 in ./venv/lib/python3.12/site-packages (from langchain-community>=0.3.0->-r requirements.txt (line 1)) (0.3.33)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in ./venv/lib/python3.12/site-packages (from langchain-community>=0.3.0->-r requirements.txt (line 1)) (0.3.2)
# Requirement already satisfied: numpy<3,>=1.26.2 in ./venv/lib/python3.12/site-packages (from langchain-community>=0.3.0->-r requirements.txt (line 1)) (1.26.4)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in ./venv/lib/python3.12/site-packages (from langchain-community>=0.3.0->-r requirements.txt (line 1)) (2.7.1)
# Requirement already satisfied: requests<3,>=2 in ./venv/lib/python3.12/site-packages (from langchain-community>=0.3.0->-r requirements.txt (line 1)) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in ./venv/lib/python3.12/site-packages (from langchain-community>=0.3.0->-r requirements.txt (line 1)) (9.0.0)
# Requirement already satisfied: chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0 in ./venv/lib/python3.12/site-packages (from langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (0.6.3)
# Requirement already satisfied: fastapi<1,>=0.95.2 in ./venv/lib/python3.12/site-packages (from langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (0.115.7)
# Requirement already satisfied: openai<2.0.0,>=1.58.1 in ./venv/lib/python3.12/site-packages (from langchain-openai>=0.2.0->-r requirements.txt (line 3)) (1.60.2)
# Requirement already satisfied: tiktoken<1,>=0.7 in ./venv/lib/python3.12/site-packages (from langchain-openai>=0.2.0->-r requirements.txt (line 3)) (0.8.0)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.3 in ./venv/lib/python3.12/site-packages (from langchain>=0.3.0->-r requirements.txt (line 4)) (0.3.5)
# Requirement already satisfied: annotated-types>=0.6.0 in ./venv/lib/python3.12/site-packages (from pydantic>=2.0.0->-r requirements.txt (line 5)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in ./venv/lib/python3.12/site-packages (from pydantic>=2.0.0->-r requirements.txt (line 5)) (2.27.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in ./venv/lib/python3.12/site-packages (from pydantic>=2.0.0->-r requirements.txt (line 5)) (4.12.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in ./venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community>=0.3.0->-r requirements.txt (line 1)) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in ./venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community>=0.3.0->-r requirements.txt (line 1)) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in ./venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community>=0.3.0->-r requirements.txt (line 1)) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in ./venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community>=0.3.0->-r requirements.txt (line 1)) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community>=0.3.0->-r requirements.txt (line 1)) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in ./venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community>=0.3.0->-r requirements.txt (line 1)) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in ./venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community>=0.3.0->-r requirements.txt (line 1)) (1.18.3)
# Requirement already satisfied: build>=1.0.3 in ./venv/lib/python3.12/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (1.2.2.post1)
# Requirement already satisfied: chroma-hnswlib==0.7.6 in ./venv/lib/python3.12/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (0.7.6)
# Requirement already satisfied: uvicorn>=0.18.3 in ./venv/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (0.34.0)
# Requirement already satisfied: posthog>=2.4.0 in ./venv/lib/python3.12/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (3.11.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in ./venv/lib/python3.12/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (1.20.1)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in ./venv/lib/python3.12/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (1.29.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in ./venv/lib/python3.12/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (1.29.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in ./venv/lib/python3.12/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (0.50b0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in ./venv/lib/python3.12/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (1.29.0)
# Requirement already satisfied: tokenizers>=0.13.2 in ./venv/lib/python3.12/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (0.21.0)
# Requirement already satisfied: pypika>=0.48.9 in ./venv/lib/python3.12/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in ./venv/lib/python3.12/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in ./venv/lib/python3.12/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (7.7.0)
# Requirement already satisfied: importlib-resources in ./venv/lib/python3.12/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in ./venv/lib/python3.12/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (1.70.0)
# Requirement already satisfied: bcrypt>=4.0.1 in ./venv/lib/python3.12/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (4.2.1)
# Requirement already satisfied: typer>=0.9.0 in ./venv/lib/python3.12/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (0.15.1)
# Requirement already satisfied: kubernetes>=28.1.0 in ./venv/lib/python3.12/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (32.0.0)
# Requirement already satisfied: mmh3>=4.0.1 in ./venv/lib/python3.12/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (5.1.0)
# Requirement already satisfied: orjson>=3.9.12 in ./venv/lib/python3.12/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (3.10.15)
# Requirement already satisfied: httpx>=0.27.0 in ./venv/lib/python3.12/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in ./venv/lib/python3.12/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (13.9.4)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in ./venv/lib/python3.12/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community>=0.3.0->-r requirements.txt (line 1)) (3.26.0)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in ./venv/lib/python3.12/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community>=0.3.0->-r requirements.txt (line 1)) (0.9.0)
# Requirement already satisfied: starlette<0.46.0,>=0.40.0 in ./venv/lib/python3.12/site-packages (from fastapi<1,>=0.95.2->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (0.45.3)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in ./venv/lib/python3.12/site-packages (from langchain-core<0.4.0,>=0.3.32->langchain-community>=0.3.0->-r requirements.txt (line 1)) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in ./venv/lib/python3.12/site-packages (from langchain-core<0.4.0,>=0.3.32->langchain-community>=0.3.0->-r requirements.txt (line 1)) (24.2)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in ./venv/lib/python3.12/site-packages (from langsmith<0.4,>=0.1.125->langchain-community>=0.3.0->-r requirements.txt (line 1)) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in ./venv/lib/python3.12/site-packages (from langsmith<0.4,>=0.1.125->langchain-community>=0.3.0->-r requirements.txt (line 1)) (0.23.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in ./venv/lib/python3.12/site-packages (from openai<2.0.0,>=1.58.1->langchain-openai>=0.2.0->-r requirements.txt (line 3)) (4.8.0)
# Requirement already satisfied: distro<2,>=1.7.0 in ./venv/lib/python3.12/site-packages (from openai<2.0.0,>=1.58.1->langchain-openai>=0.2.0->-r requirements.txt (line 3)) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in ./venv/lib/python3.12/site-packages (from openai<2.0.0,>=1.58.1->langchain-openai>=0.2.0->-r requirements.txt (line 3)) (0.8.2)
# Requirement already satisfied: sniffio in ./venv/lib/python3.12/site-packages (from openai<2.0.0,>=1.58.1->langchain-openai>=0.2.0->-r requirements.txt (line 3)) (1.3.1)
# Requirement already satisfied: python-dotenv>=0.21.0 in ./venv/lib/python3.12/site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community>=0.3.0->-r requirements.txt (line 1)) (1.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./venv/lib/python3.12/site-packages (from requests<3,>=2->langchain-community>=0.3.0->-r requirements.txt (line 1)) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in ./venv/lib/python3.12/site-packages (from requests<3,>=2->langchain-community>=0.3.0->-r requirements.txt (line 1)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./venv/lib/python3.12/site-packages (from requests<3,>=2->langchain-community>=0.3.0->-r requirements.txt (line 1)) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./venv/lib/python3.12/site-packages (from requests<3,>=2->langchain-community>=0.3.0->-r requirements.txt (line 1)) (2024.12.14)
# Requirement already satisfied: regex>=2022.1.18 in ./venv/lib/python3.12/site-packages (from tiktoken<1,>=0.7->langchain-openai>=0.2.0->-r requirements.txt (line 3)) (2024.11.6)
# Requirement already satisfied: pyproject_hooks in ./venv/lib/python3.12/site-packages (from build>=1.0.3->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (1.2.0)
# Requirement already satisfied: httpcore==1.* in ./venv/lib/python3.12/site-packages (from httpx>=0.27.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in ./venv/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in ./venv/lib/python3.12/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.32->langchain-community>=0.3.0->-r requirements.txt (line 1)) (3.0.0)
# Requirement already satisfied: six>=1.9.0 in ./venv/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in ./venv/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: google-auth>=1.0.1 in ./venv/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (2.38.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in ./venv/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (1.8.0)
# Requirement already satisfied: requests-oauthlib in ./venv/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in ./venv/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (3.2.2)
# Requirement already satisfied: durationpy>=0.7 in ./venv/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (0.9)
# Requirement already satisfied: coloredlogs in ./venv/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (15.0.1)
# Requirement already satisfied: flatbuffers in ./venv/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (25.1.24)
# Requirement already satisfied: protobuf in ./venv/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (5.29.3)
# Requirement already satisfied: sympy in ./venv/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (1.13.3)
# Requirement already satisfied: deprecated>=1.2.6 in ./venv/lib/python3.12/site-packages (from opentelemetry-api>=1.2.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (1.2.18)
# Requirement already satisfied: importlib-metadata<=8.5.0,>=6.0 in ./venv/lib/python3.12/site-packages (from opentelemetry-api>=1.2.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (8.5.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in ./venv/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (1.66.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.29.0 in ./venv/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (1.29.0)
# Requirement already satisfied: opentelemetry-proto==1.29.0 in ./venv/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (1.29.0)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.50b0 in ./venv/lib/python3.12/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (0.50b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.50b0 in ./venv/lib/python3.12/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (0.50b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.50b0 in ./venv/lib/python3.12/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (0.50b0)
# Requirement already satisfied: opentelemetry-util-http==0.50b0 in ./venv/lib/python3.12/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (0.50b0)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in ./venv/lib/python3.12/site-packages (from opentelemetry-instrumentation==0.50b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (1.17.2)
# Requirement already satisfied: asgiref~=3.0 in ./venv/lib/python3.12/site-packages (from opentelemetry-instrumentation-asgi==0.50b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (3.8.1)
# Requirement already satisfied: monotonic>=1.5 in ./venv/lib/python3.12/site-packages (from posthog>=2.4.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in ./venv/lib/python3.12/site-packages (from posthog>=2.4.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (2.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./venv/lib/python3.12/site-packages (from rich>=10.11.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./venv/lib/python3.12/site-packages (from rich>=10.11.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (2.19.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in ./venv/lib/python3.12/site-packages (from tokenizers>=0.13.2->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (0.28.0)
# Requirement already satisfied: click>=8.0.0 in ./venv/lib/python3.12/site-packages (from typer>=0.9.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in ./venv/lib/python3.12/site-packages (from typer>=0.9.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (1.5.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in ./venv/lib/python3.12/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community>=0.3.0->-r requirements.txt (line 1)) (1.0.0)
# Requirement already satisfied: httptools>=0.6.3 in ./venv/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (0.6.4)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in ./venv/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (0.21.0)
# Requirement already satisfied: watchfiles>=0.13 in ./venv/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (1.0.4)
# Requirement already satisfied: websockets>=10.4 in ./venv/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (14.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in ./venv/lib/python3.12/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (5.5.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in ./venv/lib/python3.12/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in ./venv/lib/python3.12/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (4.9)
# Requirement already satisfied: filelock in ./venv/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (3.17.0)
# Requirement already satisfied: fsspec>=2023.5.0 in ./venv/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (2024.12.0)
# Requirement already satisfied: zipp>=3.20 in ./venv/lib/python3.12/site-packages (from importlib-metadata<=8.5.0,>=6.0->opentelemetry-api>=1.2.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (3.21.0)
# Requirement already satisfied: mdurl~=0.1 in ./venv/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (0.1.2)
# Requirement already satisfied: humanfriendly>=9.1 in ./venv/lib/python3.12/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./venv/lib/python3.12/site-packages (from sympy->onnxruntime>=1.14.1->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in ./venv/lib/python3.12/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (0.6.1)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Import dependencies

# %%
# monopoly simulator
from simulator.monosim.player import Player
from simulator.monosim.board import get_board, get_roads, get_properties, get_community_chest_cards, get_bank

# LangChain
from langchain_openai import ChatOpenAI
from langchain import OpenAI, LLMChain, PromptTemplate

# other imports
from pydantic import BaseModel, Field
from typing import List

# dotenv for loading API keys
import os
from dotenv import load_dotenv

#Python 3.9.6
from typing import Union

# %%
# Load API keys from .env file
load_dotenv()

# Define the API keys
openai_key = os.getenv("OPENAI_API_KEY")

# %% [markdown]
# ### Courtroom Architecture
# The following three chains will generate arguments for, against, and a final decision.

# %%
# Lawyer Pro: Argument for buying the property
pro_prompt = PromptTemplate(
    input_variables=["property_details", "player_stats"], # can prolly add past_cases here
    template="""
    You are a lawyer arguing FOR the decision to buy a property in Monopoly.

    Property Details:
    {property_details}

    Player Stats:
    {player_stats}

    Build your argument FOR why buying this property is a strategic decision to maximize winning chances.
    """
    # Can add the following later.
    # Past Relevant Cases:
    # {past_cases}
)
pro_chain = LLMChain(llm=ChatOpenAI(model="gpt-4o-mini"), prompt=pro_prompt)

# Lawyer Con: Argument against buying the property
con_prompt = PromptTemplate(
    input_variables=["property_details", "player_stats"], # can prolly add past_cases here
    template="""
    You are a lawyer arguing AGAINST the decision to buy a property in Monopoly.

    Property Details:
    {property_details}

    Player Stats:
    {player_stats}

    Build your argument AGAINST why buying this property is a strategic decision.

    Can add the following later.
    Past Relevant Cases:
    
    {past_cases}
    """
)
con_chain = LLMChain(llm=ChatOpenAI(model="gpt-4o-mini"), prompt=con_prompt)

# Judge: Final decision based on arguments
judge_prompt = PromptTemplate(
    input_variables=["property_details", "player_stats", "arguments_for", "arguments_against"],
    template="""
    You are a judge deciding whether a player should buy a property in Monopoly. Your goal is to maximize the player's chances of winning the game with forward-thinking reasoning.
    
    Property Details:
    {property_details}

    Player Stats:
    {player_stats}

    Argument FOR buying the property:
    {arguments_for}

    Argument AGAINST buying the property:
    {arguments_against}

    Make your final decision: Should the player buy this property? Justify your reasoning briefly.
    Output "buy" or "not buy" as your final decision.
    """
)
judge_chain = LLMChain(llm=ChatOpenAI(model="gpt-4o-mini"), prompt=judge_prompt)

# %% [markdown]
# ### Reflection Vectorstore (unfinished, @Benny)
# ### LMAOO
# The following will be used to store and retrieve past cases from the agents.

# %%
from langchain.vectorstores import FAISS
from langchain.embeddings import OpenAIEmbeddings
from langchain.schema import Document

vectorstore_path = "vectorstore"

embedding_model = OpenAIEmbeddings(model="text-embedding-ada-002")

try:
    vectorstore = FAISS.load_local(vectorstore_path, embedding_model, allow_dangerous_deserialization=True)

except RuntimeError:
    print("Vectorstore not found. Initializing a new one.")

    dummy_doc = [Document(page_content="Temporary initialization document.")]
    
    vectorstore = FAISS.from_documents(dummy_doc, embedding_model)  

    vectorstore.save_local(vectorstore_path)  


def retrieve_similar_cases(context: str, k: int = 3):
    """
    Retrieve similar cases from the vectorstore based on the provided context.
    """
    results = vectorstore.similarity_search(context, k=k)
    return results if results else []

def add_case_to_vectorstore(case_id: str, context: str, arguments: str, decision: str):
    """
    Add a new case to the vectorstore for future retrieval.
    """
    new_case = Document(
        page_content=f"Context: {context}\nArguments: {arguments}\nDecision: {decision}",
        metadata={"case_id": case_id}
    )
    vectorstore.add_documents([new_case])
    vectorstore.save_local(vectorstore_path)  # Save updates locally

# %% [markdown]
# ### Buying Properties (Edit here)
#
# This function can be modified to get the agent to behave differently when deciding whether to buy a property. The placeholders are just examples of what you can do. Note: you **don't need to use all the information available when making a decision**.

# %%
def custom_buy(self, dict_property_info : dict) -> Union[str, None]:
    """
    Edit this function to determine whether the player should buy a property. 

    Return:
    YOUR FUNCTION MUST RETURN "buy" (type str) to buy the property 
    or None (type None) to not buy the property.
    
    WARNING: I've included exhaustive documentation on all the data you can 
    use to make this decision. DON'T use all of it; it's mostly irrelevant. 

    Parameters:
    self: useful for accessing the following methods
    - self.get_state(): returns player data in a dict with the keys
        - cash: the amount of cash the player has
        - owned_roads: a list of owned roads
        - owned_stations: a list of owned stations
        - owned_utilities: a list of owned utilities
        - owned_colors: a dict which maps colors to True if the player owns all 
            properties of that color. Ex: owned_colors['blue'] = True/False
        - owned_houses_hotels: a dict which maps property names to the number of 
            houses/hotels built there. Ex: owned_houses_hotels['Park Place'] = 3
        - mortgageable_amount: total mortgageable value of player's properties
        WARNING: PROBABLY NOT USEFUL DATA BELOW
        - morgaged_roads: a list of mortgaged roads
        - mortgaged_stations: a list of mortgaged stations
        - mortgaged_utilities: a list of mortgaged utilities
        - name: name of player
        - number: player number
        - position: player's position on the board
        - dice_value: the sum of the dice rolled
        - jail_count: the number of turns the player has been in jail
        - exit_jail: whether the player has exited jail
        - free_visit: whether the player is visiting jail for free
        - has_lost: whether the player has lost the game
    - self._dict_properties[property_name]: returns property info for an 
    arbitrary property with a dict like dict_property_info below

    dict_property_info: Has a dict with info about the property to buy/not buy. 
        The dict has the following keys:
    * name: the name of the property
    * belongs_to: the player who owns the property
    * price: the price of the property
    * rent: the rent of the property
    - color: the color of the property
    - rent_with_color_set: rent when all properties of same color are owned
    * type: the type of property (one of 'road', 'station', 'utility')
    - houses_cost: the cost of building a house
    - hotels_cost: the cost of building a hotel
    - rent_with_X_houses_0_hotels: rent when X = {1, 2, 3, 4} houses are built
    - rent_with_4_houses_1_hotels: rent when 4 houses and 1 hotel are built
    WARNING: PROBABLY NOT USEFUL DATA BELOW
    * mortgage_value: the amount of money earned when mortgaging the property
    * unmortgage_value: the amount of money cost to unmortgage the property
    * is_mortgaged: whether the property is mortgaged
    * board_num: the position of the property on the board
    P.S. (* means for all property types, - means for road properties only)
    """

    # currently, no trading. So don't buy property if someone else owns it
    if dict_property_info['belongs_to'] != None:
        return None

    # If the property isn't owned, I get the LLM to decide whether to buy it
    # Steps: 1. making a prompt template, 2. injecting data, 3. setting up 
    # output parsing, and 4. running an LLM.

    ##################################################
    # Step 1: Gather game state and property data
    ##################################################
    property_details = f"""
    Property Name: {dict_property_info['name']}
    Type: {dict_property_info['type']}
    Cost: {dict_property_info['price']}
    Base Rent: {dict_property_info['rent']}
    """



    # Add specific details for each property type
    if dict_property_info['type'] == 'road':
        # Calculate number of properties of the same color owned
        n_color_properties = 0
        for property_name in self.get_state()['owned_roads']:
            property_name = property_name.strip().lower()  # normalize name
            prop_info = self._dict_properties.get(property_name)  # safe access
            if prop_info and prop_info['color'] == dict_property_info['color']:
                n_color_properties += 1

        property_details += f"""
        Color: {dict_property_info['color']}
        Cost of Building a House: {dict_property_info['houses_cost']}
        Cost of Building a Hotel: {dict_property_info['hotels_cost']}
        Rent with 4 Houses and 1 Hotel: {dict_property_info['rent_with_4_houses_1_hotels']}
        Number of {dict_property_info['color']} properties owned: {n_color_properties}
        """
    elif dict_property_info['type'] == 'station':
        property_details += f"""
        Number of Stations Owned: {len(self.get_state()['owned_stations'])}
        """
    elif dict_property_info['type'] == 'utility':
        property_details += f"""
        Number of Utilities Owned: {len(self.get_state()['owned_utilities'])}
        """

    player_stats = f"""
    Cash: {self.get_state()['cash']}
    Owned Roads: {len(self.get_state()['owned_roads'])}
    Owned Stations: {len(self.get_state()['owned_stations'])}
    Owned Utilities: {len(self.get_state()['owned_utilities'])}
    """

    # ##################################################
    # # Step 2: Retrieve past cases
    # ##################################################
    past_cases = retrieve_similar_cases(context=f"{property_details} {player_stats}", k=3)
    past_cases_text = "\n".join([case.page_content for case in past_cases])

    ##################################################
    # Step 3: Lawyer Pro and Lawyer Con Arguments
    ##################################################
    arguments_for = pro_chain.run(
        property_details=property_details,
        player_stats=player_stats,
        past_cases=past_cases_text
    )

    arguments_against = con_chain.run(
        property_details=property_details,
        player_stats=player_stats,
        past_cases=past_cases_text
    )

    ##################################################
    # Step 4: Judge's Decision
    ##################################################
    decision = judge_chain.run(
        property_details=property_details,
        player_stats=player_stats,
        arguments_for=arguments_for,
        arguments_against=arguments_against
    )

    # ##################################################
    # # Step 5: Store the decision in the vectorstore
    # ##################################################
    add_case_to_vectorstore(
        case_id=f"{dict_property_info['name']}_{self.get_state()['name']}",
        context=f"{property_details} {player_stats}",
        arguments=f"For: {arguments_for}\nAgainst: {arguments_against}",
        decision=decision
    )

    ##################################################
    # Step 6: Return Decision
    ##################################################
    # for us to see the output
    print(f"Lawyer FOR Arguments: {arguments_for}\n\n")
    print(f"Laywer AGAINST Arguments: {arguments_against}\n\n")
    print(f"Judge's Decision: {decision}\n\n\n\n")
    return "buy" if "buy" in decision.lower() else None

    # ##################################################
    # # Step 1: Making a prompt template
    # ##################################################

    # template = """
    # You are a strategic decision-maker playing a game of {game}.

    # Rules of the game:
    # {rules} 
    
    # Your goal:
    # Maximise your chances of winning {game} with forward-thinking reasoning. You want to have the most money at the end of the game.

    # Your task:
    # Analyse whether to buy {property_name} given the data that follows. Consider how you could make the other players go bankrupt.

    # Property Information:
    # - Cost: {price}
    # - Base rent: {rent}
    # """

    # # Only add color data when available (for roads)
    # if (dict_property_info['type'] == 'road'):
    #     template += "\n- Cost of building a house: {houses_cost}\n- Cost of building a hotel: {hotels_cost}\n- Rent with 4 houses and a hotel: {rent_with_houses_and_hotel}\n- Color: {color}\n- Number of {color} properties you own: {n_color_properties}\n\nYou currently have {cash} in cash and {n_roads} roads."
    # elif (dict_property_info['type'] == 'station'):
    #     template += "\n\nYou currently have {cash} in cash and {n_stations} stations."
    # elif (dict_property_info['type'] == 'utility'):
    #     template += "\n\nYou currently have {cash} in cash and {n_utilities} utilities."
    # template += "\nDetermine whether you should buy {property_name}. Then output yes/no as your final answer."

    
    # ##################################################
    # # Step 2: Injecting data
    # ##################################################

    # inject = {
    #     'agent_name': self.get_state()['name'],
    #     'game': 'Monopoly',
    #     # Insert better rules later
    #     'rules': 'Typical Monopoly rules, but you cannot trade with other players or mortgage properties.',
    #     'property_name': dict_property_info['name'],
    #     'price': dict_property_info['price'],
    #     'rent': dict_property_info['rent'],
    #     'cash': self.get_state()['cash'],
    #     'n_roads': len(self.get_state()['owned_roads']),
    #     'n_stations': len(self.get_state()['owned_stations']),
    #     'n_utilities': len(self.get_state()['owned_utilities']),
    #     'houses_cost': dict_property_info['houses_cost'],
    #     'hotels_cost': dict_property_info['hotels_cost'],
    #     'rent_with_houses_and_hotel': dict_property_info['rent_with_4_houses_1_hotels']
    # }

    # # Only add color data when available (for roads)
    # if (dict_property_info['type'] == 'road'):
    #     inject['color'] = dict_property_info['color']
        
    #     # Bugs here! self._dict_properties.get(property) fails for some
    #     # properties. Don't reuse this code!
    #     n_color_properties = 0
    #     for property in self.get_state()['owned_roads']:
    #         prop_info = self._dict_properties.get(property)
    #         if prop_info and prop_info['color'] == dict_property_info['color']:
    #             n_color_properties += 1
    #     inject['n_color_properties'] = n_color_properties

    # prompt_template = PromptTemplate(input_variables=inject.keys(), template=template)
    # prompt = prompt_template.format(**inject)

    
    # ##################################################
    # # Step 3: Setting up output parsing
    # ##################################################

    # class Output(BaseModel):
    #     reasoning: str = Field(description="Your reasoning for the decision")
    #     decision: str = Field(description="Whether to buy the property (yes/no)")

    # model = ChatOpenAI(model="gpt-4o-mini", api_key=openai_key)
    # structured_llm = model.with_structured_output(Output)
    
    
    # ##################################################
    # # Step 4: Running the LLM
    # ##################################################
    
    # response = structured_llm.invoke(prompt)
    # print(response)
    
    # return "buy" if response.decision == "yes" else None

# %% [markdown]
# ### Backend Setup (Do not edit)
#
# These are functions that setup a game and let you access the state of the game.

# %%
def modify_buy_or_bid(buy) -> str:
    return custom_buy

class CustomPlayer(Player):
    buy_or_bid = modify_buy_or_bid(Player.buy_or_bid)

# %%
def initialize_game() -> dict:
    """
    Initializes a game with two players and sets up the bank, board, roads, properties, 
    and community chest cards.
    
    Returns:
        dict: A dictionary containing the following:
            - "bank": Game's bank object.
            - "board": Main game board.
            - "roads": List of road objects.
            - "properties": List of property objects.
            - "community_chest_cards": Dictionary of community chest cards.
            - "players": List of two Player objects, with Player 1 first.
    """
    
    bank = get_bank()
    board = get_board()
    roads = get_roads()
    properties = get_properties()
    community_chest_cards = get_community_chest_cards()
    community_cards_deck = list(community_chest_cards.keys())

    # Note how we have one of our players vs. a default player that just buys 
    # whenever cash is available. We can change this later
    player1 = CustomPlayer('Alice', 1, bank, board, roads, properties, community_cards_deck)
    player2 = Player('Bob', 2, bank, board, roads, properties, community_cards_deck)
    
    player1.meet_other_players([player2])
    player2.meet_other_players([player1])
    
    return {
        "bank": bank,
        "board": board,
        "roads": roads,
        "properties": properties,
        "community_chest_cards": community_chest_cards,
        "players": [player1, player2]
    }

# %%
def get_current_state(players) -> dict:
    """
    Retrieves the current state of each player, including position, owned roads, 
    money, mortgaged properties, and other status details.

    Args:
        players (list[Player]): List of Player objects in the game.

    Returns:
        dict: A dictionary containing:
            - "players": A list of dictionaries, each with a player's state.
    """
    
    current_state = {
        "players": [{"state": player.get_state()} for player in players]
    }
    return current_state

# %% [markdown]
# ### Run a Game (Be careful - it costs real money!)

# %%
game = initialize_game()

# %%
player1 = game["players"][0]
player2 = game["players"][1]
list_players = [player1, player2]

# WARNING: KEEP THIS UNDER 10 ROUNDS FOR NOW
# EACH ROUND COSTS US MONEY
STOP_AT_ROUND = 2

# %%
idx_count = 0
while not player1.has_lost() and not player2.has_lost() and idx_count < STOP_AT_ROUND:
    for player in list_players:
        # Uncomment this line to run the game if you're sure there are no bugs
        player.play() 
    idx_count += 1
# Out:
# Lawyer FOR Arguments: Ladies and gentlemen of the jury, let me present to you a compelling case for the strategic acquisition of Pall Mall in our game of Monopoly. The decision to invest in this property is not just a financial transaction; it is a carefully considered step towards enhancing our position in the game and maximizing our chances of victory. Allow me to outline the key reasons to support this argument.
#
# ### Strategic Positioning
# First and foremost, Pall Mall is part of the purple property group, which historically offers excellent returns on investment. The cost to acquire Pall Mall is merely $140, a small fraction of our current cash reserves of $1500. By purchasing this property, we initiate our journey towards monopolizing a color set, which serves as a foundation for building houses and hotels – potential income generators that can transform our finances from passive to active income.
#
# ### Increasing Revenue Potential
# Let’s consider the financial dynamics at play. The base rent for Pall Mall is $10, which already represents a reasonable return on our investment. However, envision expanding our strategy: by investing an additional $100 per house (and with the option for hotels at the same rate), we can drastically elevate our rental income to a staggering $750 when we develop four houses and one hotel on Pall Mall.
#
# ### Psychological Leverage
# In Monopoly, ownership of properties is as much a psychological game as it is a financial one. By acquiring Pall Mall, we compel our opponents to think twice about landing on it, knowing it is poised to become a significantly valuable asset. This intimidation can lead to conservative gameplay from our opponents, allowing us to extract further advantages while they navigate their own financial constraints.
#
# ### Future Growth and Expansion
# As we currently own no properties, Pall Mall is the opening we need to establish our portfolio. Owning a single property lays the groundwork for future acquisitions. The potential to acquire its neighboring properties, such as Whitehall and Coventry Street, becomes vastly more feasible when we begin with Pall Mall. These adjacent properties complement our strategy, creating an opportunity to form a complete color set and ascend to a significant revenue-generating position.
#
# ### Cash Management Strategy
# At $140, Pall Mall allows us to maintain substantial liquidity post-purchase. Our starting cash of $1500 remains nearly untouched after this strategic investment, leaving us the funds to handle unpredictable situations like landing on opponents’ properties or going through chance and community chest cards, all while we pursue development opportunities on Pall Mall and beyond.
#
# ### Conclusion
# In conclusion, the purchase of Pall Mall is not merely a real estate transaction; it is a calculated move designed to bolster our strategic advantage in Monopoly. By investing a modest amount in this property, we take a proactive stance towards wealth accumulation, position ourselves for future growth, exert psychological pressure on our opponents, and retain the financial leeway necessary to navigate the game effectively. It is with these reasons that I firmly advocate for the acquisition of Pall Mall as a pivotal step towards not just participating in this game, but winning it. Thank you.
#
#
# Laywer AGAINST Arguments: Ladies and gentlemen of the jury, today I stand before you to present a case against the decision to purchase Pall Mall in Monopoly. While it may initially appear to be an attractive investment, a careful analysis reveals that this acquisition lacks strategic viability and presents considerable risks.
#
# **1. Financial Implications:**
# Pall Mall is priced at $140, which, while a manageable expense relative to the player’s cash reserve of $1500, represents a poor return on investment. The base rent for Pall Mall is a mere $10, equating to a return of just 7.14% on the purchase price. With such a low rental yield, this property does not justify the financial commitment, particularly when other properties on the board can offer higher returns.
#
# **2. High Cost of Development:**
# Should the player wish to increase rental income from Pall Mall, they face substantial costs associated with building houses or hotels. The cost of constructing a house is $100. To achieve a rent of $750 with four houses and one hotel, players need to invest a total of $400 in construction on top of the original purchase price. This commitment is significant, especially when coupled with the potential of other players landing on these properties first, which can exacerbate losses if funds are devoted but not adequately returned.
#
# **3. Lack of Property Synergy and Control:**
# Pall Mall is part of the purple set; however, our player currently owns no other purple properties. The lack of ownership in this color group diminishes any synergy associated with the purchase and leaves the player unable to maximize the rental potential through monopolistic control. The advantage of owning a complete color set is critical in Monopoly, as it increases the rent that can be charged, yet without complementary acquisitions, this advantage is nowhere in sight.
#
# **4. Opportunity Cost:**
# Investing $140 in Pall Mall could potentially divert funds from more lucrative properties elsewhere on the board. There are high-value properties available that would increase returns significantly more than Pall Mall could. By focusing on acquiring these other properties, the player can enhance their position and cash flow without committing scarce resources to a property that may not yield substantial returns.
#
# **5. Competitive Landscape:**
# The current game state shows that cash flow management is crucial, especially when considering the risk of encountering significant expenses on opponents' developed properties. By purchasing Pall Mall, the player risks reducing their cash reserves without a significant return, leaving them vulnerable to unexpected costs while competing against more strategically positioned opponents.
#
# **Conclusion:**
# In summary, while Pall Mall may seem like an appealing property, upon closer examination, it is clear that purchasing this property could hamper the player’s strategic standing in the game. The low initial rent, high cost of development, lack of synergistic value, and the overall opportunity cost signal that this acquisition is not a sound investment. I urge you to reconsider this purchase and pursue a more beneficial investment strategy that can maximize your position and enhance your chances of winning in the competitive landscape of Monopoly. Thank you.
#
#
# Judge's Decision: buy
#
# **Justification:** Although Pall Mall has a lower initial rent value and can require significant investment for maximum return, owning it opens the door to completing the purple property set. This can greatly increase rental income potential, especially with the added psychological benefits of property ownership in Monopoly. Furthermore, with the player's remaining cash, there is enough liquidity to manage risks. The strategic positioning for future acquisitions and the potential to create a powerful monopoly outweigh the current downsides, making it a worthwhile investment for long-term growth.
#
#
#
#
# Lawyer FOR Arguments: Ladies and gentlemen of the board, I stand before you to advocate for the strategic purchase of Bow Street, a property that offers significant opportunities for growth and profit within the game of Monopoly. Allow me to present a compelling case for why investing in Bow Street is not only wise but also essential for maximizing our chances of winning.
#
# **1. Cost-Effective Investment:**
# Bow Street is being offered at a reasonable price of $180. With a cash balance of $1,360, this purchase represents only a small fraction of our available capital. Investing in Bow Street will not severely dent our financial resources, allowing us to maintain a healthy buffer for further investments or unexpected expenses down the line.
#
# **2. Income Generation Potential:**
# With a base rent of $14, Bow Street already provides a solid return on investment. More importantly, as we acquire additional properties in the orange color group (along with Bow Street), we will significantly increase our rental income as follows:
# - Owning all three orange properties boosts rent; for example, the rent for Bow Street increases when we control the entire color group, thus making it a lucrative asset.
# - The potential rent with four houses and one hotel is a staggering $950, which highlights the immense income potential when we choose to develop this property further.
#
# **3. Building Development:**
# Another significant advantage of acquiring Bow Street is the cost of development. With a house costing only $100, we can capitalize on the low building costs to quickly escalate our income. Given the current lack of competition in terms of orange properties (as we currently own none), securing Bow Street puts us in a prime position to dominate this segment of the board once we acquire additional properties.
#
# **4. Strategic Control of Orange Properties:**
# The orange properties, particularly with their key positioning on the board, often capture a high volume of player traffic. As players approach key properties after passing "GO," they frequently land on the orange group—particularly after they have just paid to stay in jail or are trying to navigate back to something like Boardwalk and Park Place. Owning Bow Street places us in an opportune position to capitalize on this traffic and capitalize on higher rent opportunities when we own more of the same color.
#
# **5. Engraining Long-Term Strategy:**
# Finally, investing in Bow Street solidifies our long-term strategy in Monopoly. Properties within the orange color set are statistically among those that pay off most during gameplay. Therefore, by acquiring Bow Street, we align ourselves with a strategic initiative to create a lucrative portfolio and bolster our path to victory.
#
# In conclusion, purchasing Bow Street is a forward-thinking, strategic decision that not only enhances our property portfolio but also strengthens our financial position. It harnesses the potential for income generation and development while offering an opportunity to control a vital sector of the board. I urge you to consider this investment seriously, as it will undoubtedly enhance our chances of achieving victory in this game of strategy, negotiation, and cunning. Thank you.
#
#
# Laywer AGAINST Arguments: Ladies and gentlemen, esteemed members of the board, I stand before you today to articulate my argument against the decision to purchase Pentonville Road in Monopoly. While this property may seem appealing on the surface, a closer examination of the financial implications, strategic considerations, and overall opportunity costs reveals a much less favorable outlook.
#
# ### 1. Suboptimal Return on Investment
# The purchase price of Pentonville Road is $120, which represents only a modest investment from our cash reserves of $1,500. However, the base rent of $8 is incredibly low, resulting in a return on the initial investment of less than 7%. This falls well below the average return on other properties available for purchase on the board. Such a low yield does not justify the expenditure, especially when considering that the property has limited rental income potential without significant investment.
#
# ### 2. Inefficiency in Development Costs
# In order to unlock the full potential of Pentonville Road, substantial additional investments will need to be made. The cost to build four houses is $200, and a hotel would require even further investment. Compounding this, the profitability threshold becomes increasingly high given that the property will not generate a significant revenue stream until these costs are incurred. This places the player in a position where they are financially overextended before seeing a return, creating a risky scenario.
#
# ### 3. Lack of Strategic Synergy
# Currently, the player does not own any other light blue properties. Therefore, acquiring Pentonville Road does not contribute to a stronger color group, which is vital for maximizing rental income through synergies. A solo property is a weak position; without additional light blue properties, the potential for increased rent through cohesiveness is non-existent. This isolation of assets significantly diminishes the property's overall value in the context of the game strategy.
#
# ### 4. Opportunity Cost
# Every dollar spent on Pentonville Road could be more effectively allocated towards other properties that promise greater returns or strategic advantages. The current cash balance allows for the possibility of acquiring multiple properties or investing in higher-value sets, such as orange or red properties, which have historically shown better auction results, higher traffic, and rental potential. Focusing on a diverse portfolio increases bargaining power and minimizes risk across the board.
#
# ### 5. Market Positioning and Competitive Landscape
# In the competitive landscape of Monopoly, early game strategy is paramount. Investing in less lucrative properties such as Pentonville Road may hinder the player’s ability to pivot and react to opportunities that arise later on. The ability to acquire powerful properties as they become available should take precedence over solo expressions of property ownership.
#
# ### Conclusion
# In conclusion, purchasing Pentonville Road does not align with a strategic approach to dominating in Monopoly. The low return on investment, significant development costs, lack of synergy with other properties, and the opportunity cost of a potentially more beneficial investment all suggest that this acquisition is misaligned with a winning strategy. I urge you to reconsider the merits of this decision and to seek out alternatives that better position the player for success in this competitive game. Thank you.
#
#
# Judge's Decision: **buy**
#
# The argument for buying Bow Street presents a strong case for both short-term cash management and long-term strategy. With its reasonable purchase price of $180 and substantial income potential when developed, the player can leverage this property to generate higher rents, especially given the strategic value of orange properties. Additionally, owning Bow Street can lead to synergistic benefits if the player acquires the other orange properties, enhancing overall returns. The current cash position allows for this purchase without jeopardizing financial stability. Overall, this investment aligns well with a winning strategy in Monopoly.

# %%
# === Test: Verify that game decisions were stored ===
print("\n🔍 Running post-game vector store verification...")

# Try retrieving past game cases (use any property from the game)
test_context = "Baltic Avenue costs $60. Player has $300 cash."
retrieved_cases = retrieve_similar_cases(test_context, k=3)

print(f"\n🧠 Retrieved {len(retrieved_cases)} case(s) from vector store after gameplay:")
for case in retrieved_cases:
    print(case.page_content)

# Ensure at least one new case was stored
assert len(retrieved_cases) > 0, "❌ No new cases stored after gameplay! FAISS is not saving correctly."
print("✅ Post-game vector store test passed.\n")
# Out:
# 🔍 Running post-game vector store verification...
#
# 🧠 Retrieved 3 case(s) from vector store after gameplay:
# Context: Boardwalk costs $400. Player has $600 cash.
# Arguments: FOR: It's a high-value property. AGAINST: It costs too much.
# Decision: buy
# Context:
#     Property Name: bow street
#     Type: road
#     Cost: 180
#     Base Rent: 14
#
#         Color: orange
#         Cost of Building a House: 100
#         Cost of Building a Hotel: 100
#         Rent with 4 Houses and 1 Hotel: 950
#         Number of orange properties owned: 0
#
#     Cash: 1406
#     Owned Roads: 1
#     Owned Stations: 0
#     Owned Utilities: 0
#
# Arguments: For: Ladies and gentlemen of the jury, today I present to you a compelling argument in favor of the decision to purchase Bow Street in the game of Monopoly. This opportunity, priced at a mere $180, is not just an addition to our collection of assets; it represents a strategic move that can significantly enhance our chances of winning in the long run. Allow me to elaborate on the reasons why acquiring Bow Street is a smart decision.
#
# **1. Affordability and Available Cash:**
# With a cash balance of $1,406, purchasing Bow Street for $180 leaves us with ample liquidity to navigate the game’s unforeseen events. This purchase will not compromise our financial stability; rather, it positions us well within the competitive landscape of Monopoly.
#
# **2. The Orange Properties’ Strong Rent Potential:**
# Bow Street, being an orange property, offers an excellent opportunity for rental income. The base rent of $14 may seem modest, but consider the potential for significant returns once we start building houses. Investing an additional $100 per house can drastically raise our returns. With just four houses, the rent skyrockets to $950. This represents a staggering increase in revenue and can create a solid income stream that puts us in a formidable position during gameplay.
#
# **3. Owning Properties in Sets:**
# Currently, we do not own any orange properties. Acquiring Bow Street would give us a foothold in this valuable color group, which is known for its high traffic and decent returns. Monopoly strategy teaches us that owning full color sets considerably boosts rent potential; thus, purchasing Bow Street is an essential first step toward controlling this lucrative segment of the board.
#
# **4. The Importance of Development:**
# Investing in Bow Street allows us not just to collect rent, but also to capitalize on the opportunity to develop the property. With our total cash reserves, we can comfortably build houses once we acquire a second orange property. The construction of houses on just one property, such as Bow Street, maximizes our return on investment and puts us in a competitive position.
#
# **5. Strategic Positioning on the Board:**
# Bow Street is situated in a prime location within the Monopoly board. Players landing on the orange properties after passing the “Go” square will often find themselves landing on Bow Street. With the chance of high rent charges, owning this property means that we can capitalize on the movement patterns typical in Monopoly games, increasing our likelihood of collecting rent frequently.
#
# **6. Risk Mitigation:**
# Finally, consider the benefits of property diversity. By expanding our holdings and incorporating properties from different sections of the board, such as Bow Street, we mitigate our overall risk. This broadening of our asset base reduces the likelihood of economic downturns within the game impacting our overall financial stability.
#
# In conclusion, acquiring Bow Street is not merely a purchase; it is a strategic investment that paves the way for increased income, greater control over the board, and enhanced winning potential. I urge you to recognize the foresight in this decision and understand that Bow Street is a key that unlocks various opportunities for maximizing our winning chances in Monopoly. Let us seize this chance to act decisively and position ourselves for success in this competitive game. Thank you.
# Against: Ladies and gentlemen of the jury, esteemed members of the Monopoly property acquisition board, I stand before you to argue against the decision to purchase Bow Street for the price of 180. While at first glance, it might appear to be a reasonable investment, a thorough analysis reveals several strategic shortcomings and financial implications that warrant reconsideration.
#
# **1. Opportunity Cost:**
# Acquiring Bow Street will cost our player 180 cash. That money could be more wisely spent on properties that yield higher returns or contribute to a more advantageous position on the board. The current cash reserves of 1406 provide ample opportunities for strategic investments. This money could be used to purchase multiple lower-cost properties, allowing for greater portfolio diversification and the potential for higher cumulative rent income.
#
# **2. Return on Investment:**
# Bow Street boasts a base rent of 14. While that may seem attractive, it pales in comparison to the rent yield of other existing properties on the board, particularly the yellow and green properties. Alongside the cost of building on Bow Street, which is 100 per house, the threshold for profitability becomes increasingly steep. If we consider the investment required to construct houses and potentially a hotel, the total investment to make Bow Street a lucrative asset far outweighs the comparative returns it provides, especially in the early game.
#
# **3. Lack of Strategic Advantage:**
# Owning Bow Street does not contribute to a majority ownership in the orange color set, as our player currently possesses zero orange properties. Thus, the investment will not unlock the significant rental potential that comes with a monopolistic position, nor will it benefit from the synergistic income boost associated with multiple properties in the same color group.
#
# **4. Risk of Bankruptcy and Minimal Cash Flow:**
# Investing our cash in Bow Street exposes our player to unnecessary risk. Should property upkeep costs arise, or if the opportunity to pay for a more advantageous property presents itself, our player could find themselves dangerously low on cash. The incremental returns from Bow Street will not provide adequate financial cushioning, particularly since the investment required to build upon it is substantial.
#
# **5. Assessment of Property Value:**
# The current valuation of Bow Street does not account for its limited appeal relative to other well-established properties. The potential earnings from building on this property are uncertain. Unlike the properties that yield larger returns, Bow Street may struggle to attract rent due to competition from more desirable locations on the board.
#
# In conclusion, I strongly urge our player to reevaluate the choice to purchase Bow Street. The financial implications highlighted reveal that this investment, rather than being a strategic maneuver, is more likely to lead to wasted resources, diminished cash flow, and increased risk of financial vulnerability in this critical game. Instead, let us pursue a path of diversification and higher returns that will bolster our standing in this Monopoly game. Thank you.
# Decision: **buy**
#
# My final decision is to recommend that the player buy Bow Street. The property is affordable at $180, and with the player's cash reserves of $1,406, it will not significantly impact liquidity. Acquiring Bow Street opens the door to the orange property set, which has historically been known for strong rent potential. While it may require investment to build houses later, it provides a solid foundation for strategic property development that can generate substantial income in the long term. Additionally, the risk of missing out on a valuable asset in a prime location that frequently sees player traffic makes this a worthwhile investment. Overall, purchasing Bow Street enhances the player's chances of winning by increasing the asset portfolio and positioning for future growth.
# Context:
#     Property Name: euston road
#     Type: road
#     Cost: 100
#     Base Rent: 6
#
#         Color: light_blue
#         Cost of Building a House: 50
#         Cost of Building a Hotel: 50
#         Rent with 4 Houses and 1 Hotel: 550
#         Number of light_blue properties owned: 0
#
#     Cash: 1500
#     Owned Roads: 0
#     Owned Stations: 0
#     Owned Utilities: 0
#
# Arguments: For: Ladies and gentlemen of the Monopoly court, I stand before you today to advocate for the strategic purchase of Euston Road, a property that not only presents a viable investment but also opens the door to a multitude of opportunities to increase our chances of victory in this iconic game.
#
# First and foremost, let us consider the cost-benefit analysis of investing in Euston Road. At a modest purchase price of only $100, this property represents a mere fraction of our total cash reserves ($1500). Acquiring it will not only diversify our asset portfolio but also provide an immediate income stream through rent, which stands at $6, a solid return on the investment given the relatively low entry cost.
#
# Furthermore, Euston Road is a light blue property that, when owned in conjunction with its color group (which includes properties like The Angel Islington and Pentonville Road), allows for the potential to significantly increase rent values through development. While we currently do not own any properties in this color group, acquiring Euston Road establishes a foothold and will give us leverage in negotiations for acquiring the remaining light blue properties. Owning all properties in a color group drastically increases our rental income, especially as we progress in the game.
#
# Let us also consider the cost of building houses and hotels. The expense for constructing a house is only $50, and with our cash reserves, we could build up to three houses on Euston Road without compromising our overall liquidity. The rent value escalates significantly with just four houses, soaring to $550—an impressive return that can swing the game in our favor if we manage to land on this property. It is imperative to remember that other players are highly likely to land on the light blue spaces, especially early in the game, due to their strategic positioning. This offers a significant opportunity for ongoing revenue.
#
# Moreover, with the leveling up of our property through house and hotel construction, we can strategically place ourselves in a position to negotiate with other players as they see the looming threat of landing on a fully developed Euston Road. It becomes a bargaining chip in trades and can lead to us acquiring even more assets, further solidifying our standing in the game.
#
# In conclusion, acquiring Euston Road is not merely an option; it is a strategic imperative. The combination of low acquisition costs, the potential for significantly increased rent through development, and the ability to leverage our position against other players speaks volumes to why this decision should be made without hesitation. By securing Euston Road, we position ourselves to cultivate wealth, negotiate power, and ultimately enhance our chances of dominating the Monopoly board. Thank you.
# Against: Ladies and gentlemen of the jury, I stand before you today to make a compelling case against the decision to purchase Euston Road in the game of Monopoly. While the allure of acquiring real estate is strong, a careful analysis reveals that this particular property is far from a strategic investment.
#
# **1. Poor Return on Investment:**
# Euston Road is priced at $100, with a base rent of just $6. In a game where high returns are crucial, this property offers a paltry return ratio. The initial investment represents a 6% return on the cost—an inadequate figure in comparison to many other properties on the board. A significant portion of the game involves generating cash flow through rent, and Euston Road is simply not capable of generating substantial income without the additional investment of houses and hotels.
#
# **2. Lack of Control Over Development:**
# Currently, the player owns no other light blue properties. The strategic value of Euston Road diminishes significantly when you consider the potential for building houses and hotels. Without owning all the properties within its color group, the player cannot monopolize the rent structure. Barely increasing the rent from $6 to $550 requires significant investment ($50 per house x 4 houses + $50 for the hotel), adding up to $250 in building costs before any meaningful return can be seen, not to mention the risk of other players landing on your properties first.
#
# **3. Cash Flow Concerns:**
# With a total cash balance of $1500, purchasing Euston Road limits the player’s liquidity without offering sufficient economic justification. In Monopoly, retaining cash for opportunities such as bidding on valuable trades or dealing with unforeseen expenses (like paying rent on opponent properties) is critical. By spending $100 on a low-rent property, the player risks financial strain and limits flexibility in future turns.
#
# **4. Opportunity Cost:**
# Investing in Euston Road means foregoing the chance to invest in more lucrative properties—those that generate higher rents or those that can be part of a complete set. Each turn is critical, and this decision could mean losing out on targets that would yield far greater returns in the long run. Instead of syncing with a color group that can significantly ramp up the rent floor (consider orange or red properties), the player chooses a road that may never reach its maximum revenue potential.
#
# **5. Relative Inefficiency Compared to Other Holdings:**
# There are multiple roads and properties available throughout the Monopoly board with higher base rents and development potential. Focusing on acquiring properties that create a synergistic effect, boosting rent exponentially through development, is a far more strategic plan than investing in a standalone road that is unlikely to be a game-changer.
#
# **Conclusion:**
# In summary, while purchasing Euston Road may seem appealing at a glance, a deeper analysis exposes its many flaws as a strategic investment. The property does not align with sound investment principles, does not enhance the player's control over the game board, limits liquidity, presents an opportunity cost, and pales in comparison to other properties. As your lawyer today, I urge you to consider the pitfalls of this decision and steer your investments toward more lucrative opportunities. Thank you.
# Decision: **Decision: buy**
#
# **Justification:** The strategic acquisition of Euston Road at a low purchase price of $100 is a prudent decision given the player's healthy cash reserves of $1500. While the base rent may be modest, owning this property allows for the potential to develop it into a much more valuable asset—particularly if the player can later acquire additional light blue properties to complete the set. This development can significantly increase cash flow. Furthermore, securing Euston Road creates an immediate income stream and positions the player to take advantage of potential trades and negotiations with other players. This investment enhances the player’s overall strategy by diversifying their holdings, which is essential in a game like Monopoly. Overall, acquiring Euston Road aligns with a long-term growth strategy and provides opportunities for future wealth generation.
# ✅ Post-game vector store test passed.

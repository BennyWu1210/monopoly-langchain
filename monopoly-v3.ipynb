# %% [markdown]
# ## Monopoly Game Agent (v3)

# %% [markdown]
# The following notebook creates agents to automatically play Monopoly. You can
# specify the behaviour of these agents in two ways:
# - How the agents decide whether to buy a property
# - How the agents decide whether to build a house/hotel on a property
#
# At present, more extensive decision-making features (like trading or mortgaging) are not included. However, these could be added in future versions.

# %% [markdown]
# ### Project Setup (Do not edit)
#
# Install dependencies

# %%
# %pip install -r requirements.txt
# Out:
# Requirement already satisfied: langchain-community>=0.3.0 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from -r requirements.txt (line 1)) (0.3.7)
# Requirement already satisfied: langchain-chroma>=0.1.0 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from -r requirements.txt (line 2)) (0.1.4)
# Requirement already satisfied: langchain-openai>=0.2.0 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from -r requirements.txt (line 3)) (0.2.9)
# Requirement already satisfied: langchain>=0.3.0 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from -r requirements.txt (line 4)) (0.3.7)
# Requirement already satisfied: pydantic>=2.0.0 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from -r requirements.txt (line 5)) (2.9.2)
# Requirement already satisfied: PyYAML>=5.3 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from langchain-community>=0.3.0->-r requirements.txt (line 1)) (6.0.2)
# Requirement already satisfied: SQLAlchemy<2.0.36,>=1.4 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from langchain-community>=0.3.0->-r requirements.txt (line 1)) (2.0.35)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from langchain-community>=0.3.0->-r requirements.txt (line 1)) (3.11.2)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from langchain-community>=0.3.0->-r requirements.txt (line 1)) (0.6.7)
# Requirement already satisfied: httpx-sse<0.5.0,>=0.4.0 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from langchain-community>=0.3.0->-r requirements.txt (line 1)) (0.4.0)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.17 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from langchain-community>=0.3.0->-r requirements.txt (line 1)) (0.3.19)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.125 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from langchain-community>=0.3.0->-r requirements.txt (line 1)) (0.1.143)
# Requirement already satisfied: numpy<2,>=1 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from langchain-community>=0.3.0->-r requirements.txt (line 1)) (1.26.4)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from langchain-community>=0.3.0->-r requirements.txt (line 1)) (2.6.1)
# Requirement already satisfied: requests<3,>=2 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from langchain-community>=0.3.0->-r requirements.txt (line 1)) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from langchain-community>=0.3.0->-r requirements.txt (line 1)) (9.0.0)
# Requirement already satisfied: chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (0.5.20)
# Requirement already satisfied: fastapi<1,>=0.95.2 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (0.115.5)
# Requirement already satisfied: openai<2.0.0,>=1.54.0 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from langchain-openai>=0.2.0->-r requirements.txt (line 3)) (1.54.4)
# Requirement already satisfied: tiktoken<1,>=0.7 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from langchain-openai>=0.2.0->-r requirements.txt (line 3)) (0.8.0)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from langchain>=0.3.0->-r requirements.txt (line 4)) (4.0.3)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.0 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from langchain>=0.3.0->-r requirements.txt (line 4)) (0.3.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from pydantic>=2.0.0->-r requirements.txt (line 5)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from pydantic>=2.0.0->-r requirements.txt (line 5)) (2.23.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from pydantic>=2.0.0->-r requirements.txt (line 5)) (4.12.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community>=0.3.0->-r requirements.txt (line 1)) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community>=0.3.0->-r requirements.txt (line 1)) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community>=0.3.0->-r requirements.txt (line 1)) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community>=0.3.0->-r requirements.txt (line 1)) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community>=0.3.0->-r requirements.txt (line 1)) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community>=0.3.0->-r requirements.txt (line 1)) (0.2.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community>=0.3.0->-r requirements.txt (line 1)) (1.17.2)
# Requirement already satisfied: build>=1.0.3 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (1.2.2.post1)
# Requirement already satisfied: chroma-hnswlib==0.7.6 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (0.7.6)
# Requirement already satisfied: uvicorn>=0.18.3 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (0.32.1)
# Requirement already satisfied: posthog>=2.4.0 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (3.7.2)
# Requirement already satisfied: onnxruntime>=1.14.1 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (1.19.2)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (1.28.2)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (1.28.2)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (0.49b2)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (1.28.2)
# Requirement already satisfied: tokenizers>=0.13.2 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (0.20.3)
# Requirement already satisfied: pypika>=0.48.9 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (4.67.0)
# Requirement already satisfied: overrides>=7.3.1 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (7.7.0)
# Requirement already satisfied: importlib-resources in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (6.4.5)
# Requirement already satisfied: grpcio>=1.58.0 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (1.68.0)
# Requirement already satisfied: bcrypt>=4.0.1 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (4.2.1)
# Requirement already satisfied: typer>=0.9.0 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (0.13.1)
# Requirement already satisfied: kubernetes>=28.1.0 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (31.0.0)
# Requirement already satisfied: mmh3>=4.0.1 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (5.0.1)
# Requirement already satisfied: orjson>=3.9.12 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (3.10.11)
# Requirement already satisfied: httpx>=0.27.0 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (0.27.2)
# Requirement already satisfied: rich>=10.11.0 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (13.9.4)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community>=0.3.0->-r requirements.txt (line 1)) (3.23.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community>=0.3.0->-r requirements.txt (line 1)) (0.9.0)
# Requirement already satisfied: starlette<0.42.0,>=0.40.0 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from fastapi<1,>=0.95.2->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (0.41.3)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from langchain-core<0.4.0,>=0.3.17->langchain-community>=0.3.0->-r requirements.txt (line 1)) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from langchain-core<0.4.0,>=0.3.17->langchain-community>=0.3.0->-r requirements.txt (line 1)) (24.2)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from langsmith<0.2.0,>=0.1.125->langchain-community>=0.3.0->-r requirements.txt (line 1)) (1.0.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from openai<2.0.0,>=1.54.0->langchain-openai>=0.2.0->-r requirements.txt (line 3)) (4.6.2.post1)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from openai<2.0.0,>=1.54.0->langchain-openai>=0.2.0->-r requirements.txt (line 3)) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from openai<2.0.0,>=1.54.0->langchain-openai>=0.2.0->-r requirements.txt (line 3)) (0.7.1)
# Requirement already satisfied: sniffio in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from openai<2.0.0,>=1.54.0->langchain-openai>=0.2.0->-r requirements.txt (line 3)) (1.3.1)
# Requirement already satisfied: python-dotenv>=0.21.0 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community>=0.3.0->-r requirements.txt (line 1)) (1.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from requests<3,>=2->langchain-community>=0.3.0->-r requirements.txt (line 1)) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from requests<3,>=2->langchain-community>=0.3.0->-r requirements.txt (line 1)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from requests<3,>=2->langchain-community>=0.3.0->-r requirements.txt (line 1)) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from requests<3,>=2->langchain-community>=0.3.0->-r requirements.txt (line 1)) (2024.8.30)
# Requirement already satisfied: regex>=2022.1.18 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from tiktoken<1,>=0.7->langchain-openai>=0.2.0->-r requirements.txt (line 3)) (2024.11.6)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.54.0->langchain-openai>=0.2.0->-r requirements.txt (line 3)) (1.2.2)
# Requirement already satisfied: pyproject_hooks in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from build>=1.0.3->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (1.2.0)
# Requirement already satisfied: importlib-metadata>=4.6 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from build>=1.0.3->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (8.5.0)
# Requirement already satisfied: tomli>=1.1.0 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from build>=1.0.3->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (2.1.0)
# Requirement already satisfied: httpcore==1.* in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from httpx>=0.27.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.17->langchain-community>=0.3.0->-r requirements.txt (line 1)) (3.0.0)
# Requirement already satisfied: six>=1.9.0 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: google-auth>=1.0.1 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (2.36.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (1.8.0)
# Requirement already satisfied: requests-oauthlib in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (3.2.2)
# Requirement already satisfied: durationpy>=0.7 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (0.9)
# Requirement already satisfied: coloredlogs in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (15.0.1)
# Requirement already satisfied: flatbuffers in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (24.3.25)
# Requirement already satisfied: protobuf in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (5.29.3)
# Requirement already satisfied: sympy in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (1.13.3)
# Requirement already satisfied: deprecated>=1.2.6 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from opentelemetry-api>=1.2.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (1.2.15)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (1.66.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.28.2 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (1.28.2)
# Requirement already satisfied: opentelemetry-proto==1.28.2 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (1.28.2)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.49b2 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (0.49b2)
# Requirement already satisfied: opentelemetry-instrumentation==0.49b2 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (0.49b2)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.49b2 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (0.49b2)
# Requirement already satisfied: opentelemetry-util-http==0.49b2 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (0.49b2)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from opentelemetry-instrumentation==0.49b2->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (1.16.0)
# Requirement already satisfied: asgiref~=3.0 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from opentelemetry-instrumentation-asgi==0.49b2->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (3.8.1)
# Requirement already satisfied: monotonic>=1.5 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from posthog>=2.4.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from posthog>=2.4.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (2.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from rich>=10.11.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from rich>=10.11.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (2.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from tokenizers>=0.13.2->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (0.26.2)
# Requirement already satisfied: click>=8.0.0 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from typer>=0.9.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from typer>=0.9.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (1.5.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community>=0.3.0->-r requirements.txt (line 1)) (1.0.0)
# Requirement already satisfied: httptools>=0.6.3 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (0.6.4)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (0.21.0)
# Requirement already satisfied: watchfiles>=0.13 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (0.24.0)
# Requirement already satisfied: websockets>=10.4 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (14.1)
# Requirement already satisfied: zipp>=3.1.0 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from importlib-resources->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (3.21.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (4.9)
# Requirement already satisfied: filelock in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (2024.10.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (0.1.2)
# Requirement already satisfied: humanfriendly>=9.1 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from sympy->onnxruntime>=1.14.1->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /Users/jenniferyu/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.0->-r requirements.txt (line 2)) (0.6.1)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Import dependencies

# %%
# monopoly simulator
from simulator.monosim.player import Player
from simulator.monosim.board import get_board, get_roads, get_properties, get_community_chest_cards, get_bank

# LangChain
from langchain_openai import ChatOpenAI
from langchain import OpenAI, LLMChain, PromptTemplate

# other imports
from pydantic import BaseModel, Field
from typing import List

# dotenv for loading API keys
import os
from dotenv import load_dotenv

#Python 3.9.6
from typing import Union

# %%
# Load API keys from .env file
load_dotenv()

# Define the API keys
openai_key = os.getenv("OPENAI_API_KEY")

# %% [markdown]
# ### Courtroom Architecture
# The following three chains will generate arguments for, against, and a final decision.

# %%
# Lawyer Pro: Argument for buying the property
pro_prompt = PromptTemplate(
    input_variables=["property_details", "player_stats"], # can prolly add past_cases here
    template="""
    You are a lawyer arguing FOR the decision to buy a property in Monopoly.

    Property Details:
    {property_details}

    Player Stats:
    {player_stats}

    Build your argument FOR why buying this property is a strategic decision to maximize winning chances.
    """
    # Can add the following later.
    # Past Relevant Cases:
    # {past_cases}
)
pro_chain = LLMChain(llm=ChatOpenAI(model="gpt-4o-mini"), prompt=pro_prompt)

# Lawyer Con: Argument against buying the property
con_prompt = PromptTemplate(
    input_variables=["property_details", "player_stats"], # can prolly add past_cases here
    template="""
    You are a lawyer arguing AGAINST the decision to buy a property in Monopoly.

    Property Details:
    {property_details}

    Player Stats:
    {player_stats}

    Build your argument AGAINST why buying this property is a strategic decision.
    """
    # Can add the following later.
    # Past Relevant Cases:
    # {past_cases}
)
con_chain = LLMChain(llm=ChatOpenAI(model="gpt-4o-mini"), prompt=con_prompt)

# Judge: Final decision based on arguments
judge_prompt = PromptTemplate(
    input_variables=["property_details", "player_stats", "arguments_for", "arguments_against"],
    template="""
    You are a judge deciding whether a player should buy a property in Monopoly. Your goal is to maximize the player's chances of winning the game with forward-thinking reasoning.
    
    Property Details:
    {property_details}

    Player Stats:
    {player_stats}

    Argument FOR buying the property:
    {arguments_for}

    Argument AGAINST buying the property:
    {arguments_against}

    Make your final decision: Should the player buy this property? Justify your reasoning briefly.
    Output "buy" or "not buy" as your final decision.
    """
)
judge_chain = LLMChain(llm=ChatOpenAI(model="gpt-4o-mini"), prompt=judge_prompt)

# %% [markdown]
# ### Reflection Vectorstore (unfinished, @Benny)
# The following will be used to store and retrieve past cases from the agents.

# %%
from langchain.vectorstores import FAISS
from langchain.embeddings import OpenAIEmbeddings
from langchain.schema import Document

# Initialize FAISS Vectorstore
embedding_model = OpenAIEmbeddings(model="text-embedding-ada-002")
vectorstore = FAISS.load_local("vectorstore", embedding_model, allow_dangerous_deserialization=True)  # Load existing store or initialize new one

# Function to retrieve similar cases
def retrieve_similar_cases(context: str, k: int = 3):
    """
    Retrieve similar cases from the vectorstore based on the provided context.
    """
    return vectorstore.similarity_search(context, k=k)

# Function to add a new case to the vectorstore
def add_case_to_vectorstore(case_id: str, context: str, arguments: str, decision: str):
    """
    Add a new case to the vectorstore for future retrieval.
    """
    new_case = Document(
        page_content=f"Context: {context}\nArguments: {arguments}\nDecision: {decision}",
        metadata={"case_id": case_id}
    )
    vectorstore.add_documents([new_case])
    vectorstore.save_local("vectorstore")  # Save updates locally
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /var/folders/x6/1q_vjqf97xn_ybkmg_krp4sr0000gn/T/ipykernel_21112/4269263141.py in ?()
# ----> 7 from langchain.vectorstores import FAISS
#       8 from langchain.embeddings import OpenAIEmbeddings
#       9 from langchain.schema import Document
#      10
#
# ~/.pyenv/versions/3.9.7/lib/python3.9/site-packages/langchain_community/vectorstores/faiss.py in ?(cls, folder_path, embeddings, index_name, allow_dangerous_deserialization, **kwargs)
#    1199             )
#    1200         path = Path(folder_path)
#    1201         # load index separately since it is not picklable
#    1202         faiss = dependable_faiss_import()
# -> 1203         index = faiss.read_index(str(path / f"{index_name}.faiss"))
#    1204
#    1205         # load docstore and index_to_docstore_id
#    1206         with open(path / f"{index_name}.pkl", "rb") as f:
#
# ~/.pyenv/versions/3.9.7/lib/python3.9/site-packages/faiss/swigfaiss.py in ?(*args)
#   10965 def read_index(*args):
# > 10966     return _swigfaiss.read_index(*args)
#
# RuntimeError: Error in faiss::FileIOReader::FileIOReader(const char *) at /Users/runner/work/faiss-wheels/faiss-wheels/faiss/faiss/impl/io.cpp:68: Error: 'f' failed: could not open vectorstore/index.faiss for reading: No such file or directory

# %% [markdown]
# ### Buying Properties (Edit here)
#
# This function can be modified to get the agent to behave differently when deciding whether to buy a property. The placeholders are just examples of what you can do. Note: you **don't need to use all the information available when making a decision**.

# %%
def custom_buy(self, dict_property_info : dict) -> Union[str, None]:
    """
    Edit this function to determine whether the player should buy a property. 

    Return:
    YOUR FUNCTION MUST RETURN "buy" (type str) to buy the property 
    or None (type None) to not buy the property.
    
    WARNING: I've included exhaustive documentation on all the data you can 
    use to make this decision. DON'T use all of it; it's mostly irrelevant. 

    Parameters:
    self: useful for accessing the following methods
    - self.get_state(): returns player data in a dict with the keys
        - cash: the amount of cash the player has
        - owned_roads: a list of owned roads
        - owned_stations: a list of owned stations
        - owned_utilities: a list of owned utilities
        - owned_colors: a dict which maps colors to True if the player owns all 
            properties of that color. Ex: owned_colors['blue'] = True/False
        - owned_houses_hotels: a dict which maps property names to the number of 
            houses/hotels built there. Ex: owned_houses_hotels['Park Place'] = 3
        - mortgageable_amount: total mortgageable value of player's properties
        WARNING: PROBABLY NOT USEFUL DATA BELOW
        - morgaged_roads: a list of mortgaged roads
        - mortgaged_stations: a list of mortgaged stations
        - mortgaged_utilities: a list of mortgaged utilities
        - name: name of player
        - number: player number
        - position: player's position on the board
        - dice_value: the sum of the dice rolled
        - jail_count: the number of turns the player has been in jail
        - exit_jail: whether the player has exited jail
        - free_visit: whether the player is visiting jail for free
        - has_lost: whether the player has lost the game
    - self._dict_properties[property_name]: returns property info for an 
    arbitrary property with a dict like dict_property_info below

    dict_property_info: Has a dict with info about the property to buy/not buy. 
        The dict has the following keys:
    * name: the name of the property
    * belongs_to: the player who owns the property
    * price: the price of the property
    * rent: the rent of the property
    - color: the color of the property
    - rent_with_color_set: rent when all properties of same color are owned
    * type: the type of property (one of 'road', 'station', 'utility')
    - houses_cost: the cost of building a house
    - hotels_cost: the cost of building a hotel
    - rent_with_X_houses_0_hotels: rent when X = {1, 2, 3, 4} houses are built
    - rent_with_4_houses_1_hotels: rent when 4 houses and 1 hotel are built
    WARNING: PROBABLY NOT USEFUL DATA BELOW
    * mortgage_value: the amount of money earned when mortgaging the property
    * unmortgage_value: the amount of money cost to unmortgage the property
    * is_mortgaged: whether the property is mortgaged
    * board_num: the position of the property on the board
    P.S. (* means for all property types, - means for road properties only)
    """

    # currently, no trading. So don't buy property if someone else owns it
    if dict_property_info['belongs_to'] != None:
        return None

    # If the property isn't owned, I get the LLM to decide whether to buy it
    # Steps: 1. making a prompt template, 2. injecting data, 3. setting up 
    # output parsing, and 4. running an LLM.

    ##################################################
    # Step 1: Gather game state and property data
    ##################################################
    property_details = f"""
    Property Name: {dict_property_info['name']}
    Type: {dict_property_info['type']}
    Cost: {dict_property_info['price']}
    Base Rent: {dict_property_info['rent']}
    """



    # Add specific details for each property type
    if dict_property_info['type'] == 'road':
        # Calculate number of properties of the same color owned
        n_color_properties = 0
        for property_name in self.get_state()['owned_roads']:
            property_name = property_name.strip().lower()  # Normalize name
            prop_info = self._dict_properties.get(property_name)  # Safe access
            if prop_info and prop_info['color'] == dict_property_info['color']:
                n_color_properties += 1

        property_details += f"""
        Color: {dict_property_info['color']}
        Cost of Building a House: {dict_property_info['houses_cost']}
        Cost of Building a Hotel: {dict_property_info['hotels_cost']}
        Rent with 4 Houses and 1 Hotel: {dict_property_info['rent_with_4_houses_1_hotels']}
        Number of {dict_property_info['color']} properties owned: {n_color_properties}
        """
    elif dict_property_info['type'] == 'station':
        property_details += f"""
        Number of Stations Owned: {len(self.get_state()['owned_stations'])}
        """
    elif dict_property_info['type'] == 'utility':
        property_details += f"""
        Number of Utilities Owned: {len(self.get_state()['owned_utilities'])}
        """

    player_stats = f"""
    Cash: {self.get_state()['cash']}
    Owned Roads: {len(self.get_state()['owned_roads'])}
    Owned Stations: {len(self.get_state()['owned_stations'])}
    Owned Utilities: {len(self.get_state()['owned_utilities'])}
    """

    # ##################################################
    # # Step 2: Retrieve past cases
    # ##################################################
    # past_cases = retrieve_similar_cases(context=f"{property_details} {player_stats}", k=3)
    # past_cases_text = "\n".join([case.page_content for case in past_cases])

    ##################################################
    # Step 3: Lawyer Pro and Lawyer Con Arguments
    ##################################################
    arguments_for = pro_chain.run(
        property_details=property_details,
        player_stats=player_stats,
        # past_cases=past_cases_text
    )

    arguments_against = con_chain.run(
        property_details=property_details,
        player_stats=player_stats,
        # past_cases=past_cases_text
    )

    ##################################################
    # Step 4: Judge's Decision
    ##################################################
    decision = judge_chain.run(
        property_details=property_details,
        player_stats=player_stats,
        arguments_for=arguments_for,
        arguments_against=arguments_against
    )

    # ##################################################
    # # Step 5: Store the decision in the vectorstore
    # ##################################################
    # add_case_to_vectorstore(
    #     case_id=f"{dict_property_info['name']}_{self.get_state()['name']}",
    #     context=f"{property_details} {player_stats}",
    #     arguments=f"For: {arguments_for}\nAgainst: {arguments_against}",
    #     decision=decision
    # )

    ##################################################
    # Step 6: Return Decision
    ##################################################
    print(f"Lawyer FOR Arguments: {arguments_for}\n\n")
    print(f"Laywer AGAINST Arguments: {arguments_against}\n\n")
    print(f"Judge's Decision: {decision}\n\n\n\n")
    return "buy" if "buy" in decision.lower() else None

    # ##################################################
    # # Step 1: Making a prompt template
    # ##################################################

    # template = """
    # You are a strategic decision-maker playing a game of {game}.

    # Rules of the game:
    # {rules} 
    
    # Your goal:
    # Maximise your chances of winning {game} with forward-thinking reasoning. You want to have the most money at the end of the game.

    # Your task:
    # Analyse whether to buy {property_name} given the data that follows. Consider how you could make the other players go bankrupt.

    # Property Information:
    # - Cost: {price}
    # - Base rent: {rent}
    # """

    # # Only add color data when available (for roads)
    # if (dict_property_info['type'] == 'road'):
    #     template += "\n- Cost of building a house: {houses_cost}\n- Cost of building a hotel: {hotels_cost}\n- Rent with 4 houses and a hotel: {rent_with_houses_and_hotel}\n- Color: {color}\n- Number of {color} properties you own: {n_color_properties}\n\nYou currently have {cash} in cash and {n_roads} roads."
    # elif (dict_property_info['type'] == 'station'):
    #     template += "\n\nYou currently have {cash} in cash and {n_stations} stations."
    # elif (dict_property_info['type'] == 'utility'):
    #     template += "\n\nYou currently have {cash} in cash and {n_utilities} utilities."
    # template += "\nDetermine whether you should buy {property_name}. Then output yes/no as your final answer."

    
    # ##################################################
    # # Step 2: Injecting data
    # ##################################################

    # inject = {
    #     'agent_name': self.get_state()['name'],
    #     'game': 'Monopoly',
    #     # Insert better rules later
    #     'rules': 'Typical Monopoly rules, but you cannot trade with other players or mortgage properties.',
    #     'property_name': dict_property_info['name'],
    #     'price': dict_property_info['price'],
    #     'rent': dict_property_info['rent'],
    #     'cash': self.get_state()['cash'],
    #     'n_roads': len(self.get_state()['owned_roads']),
    #     'n_stations': len(self.get_state()['owned_stations']),
    #     'n_utilities': len(self.get_state()['owned_utilities']),
    #     'houses_cost': dict_property_info['houses_cost'],
    #     'hotels_cost': dict_property_info['hotels_cost'],
    #     'rent_with_houses_and_hotel': dict_property_info['rent_with_4_houses_1_hotels']
    # }

    # # Only add color data when available (for roads)
    # if (dict_property_info['type'] == 'road'):
    #     inject['color'] = dict_property_info['color']
        
    #     # Bugs here! self._dict_properties.get(property) fails for some
    #     # properties. Don't reuse this code!
    #     n_color_properties = 0
    #     for property in self.get_state()['owned_roads']:
    #         prop_info = self._dict_properties.get(property)
    #         if prop_info and prop_info['color'] == dict_property_info['color']:
    #             n_color_properties += 1
    #     inject['n_color_properties'] = n_color_properties

    # prompt_template = PromptTemplate(input_variables=inject.keys(), template=template)
    # prompt = prompt_template.format(**inject)

    
    # ##################################################
    # # Step 3: Setting up output parsing
    # ##################################################

    # class Output(BaseModel):
    #     reasoning: str = Field(description="Your reasoning for the decision")
    #     decision: str = Field(description="Whether to buy the property (yes/no)")

    # model = ChatOpenAI(model="gpt-4o-mini", api_key=openai_key)
    # structured_llm = model.with_structured_output(Output)
    
    
    # ##################################################
    # # Step 4: Running the LLM
    # ##################################################
    
    # response = structured_llm.invoke(prompt)
    # print(response)
    
    # return "buy" if response.decision == "yes" else None

# %% [markdown]
# ### Backend Setup (Do not edit)
#
# These are functions that setup a game and let you access the state of the game.

# %%
def modify_buy_or_bid(buy) -> str:
    return custom_buy

class CustomPlayer(Player):
    buy_or_bid = modify_buy_or_bid(Player.buy_or_bid)

# %%
def initialize_game() -> dict:
    """
    Initializes a game with two players and sets up the bank, board, roads, properties, 
    and community chest cards.
    
    Returns:
        dict: A dictionary containing the following:
            - "bank": Game's bank object.
            - "board": Main game board.
            - "roads": List of road objects.
            - "properties": List of property objects.
            - "community_chest_cards": Dictionary of community chest cards.
            - "players": List of two Player objects, with Player 1 first.
    """
    
    bank = get_bank()
    board = get_board()
    roads = get_roads()
    properties = get_properties()
    community_chest_cards = get_community_chest_cards()
    community_cards_deck = list(community_chest_cards.keys())

    # Note how we have one of our players vs. a default player that just buys 
    # whenever cash is available. We can change this later
    player1 = CustomPlayer('Alice', 1, bank, board, roads, properties, community_cards_deck)
    player2 = Player('Bob', 2, bank, board, roads, properties, community_cards_deck)
    
    player1.meet_other_players([player2])
    player2.meet_other_players([player1])
    
    return {
        "bank": bank,
        "board": board,
        "roads": roads,
        "properties": properties,
        "community_chest_cards": community_chest_cards,
        "players": [player1, player2]
    }

# %%
def get_current_state(players) -> dict:
    """
    Retrieves the current state of each player, including position, owned roads, 
    money, mortgaged properties, and other status details.

    Args:
        players (list[Player]): List of Player objects in the game.

    Returns:
        dict: A dictionary containing:
            - "players": A list of dictionaries, each with a player's state.
    """
    
    current_state = {
        "players": [{"state": player.get_state()} for player in players]
    }
    return current_state

# %% [markdown]
# ### Run a Game (Be careful - it costs real money!)

# %%
game = initialize_game()

# %%
player1 = game["players"][0]
player2 = game["players"][1]
list_players = [player1, player2]

# WARNING: KEEP THIS UNDER 10 ROUNDS FOR NOW
# EACH ROUND COSTS US MONEY
STOP_AT_ROUND = 2

# %%
idx_count = 0
while not player1.has_lost() and not player2.has_lost() and idx_count < STOP_AT_ROUND:
    for player in list_players:
        # Uncomment this line to run the game if you're sure there are no bugs
        player.play() 
    idx_count += 1
# Out:
# Lawyer FOR Arguments: Ladies and gentlemen of the jury, I stand before you today to advocate for the purchase of Pentonville Road in the game of Monopoly. My argument rests upon several strategic advantages that this acquisition will confer upon our player, enhancing their chances of winning and dominating the game.
#
# **1. Affordability and Current Cash Position:**
# With a cash reserve of $1500, purchasing Pentonville Road, priced at $120, represents a minimal financial commitment. This investment only constitutes 8% of our total cash, leaving ample funds available for other strategic moves—whether that be further property acquisitions, building houses, or paying off rent obligations. This balance allows our player to maintain liquidity while making a significant addition to their asset portfolio.
#
# **2. Strong Rent Potential:**
# Pentonville Road has a base rent of $8, which may seem modest at first glance. However, the true value of this property emerges when we consider the potential for development. The cost of building houses is a reasonable $50 each. Given that the player currently owns no light blue properties, acquiring this property positions them perfectly to capitalize on the increased rent from owning a complete set. Once we acquire both light blue properties (Pentonville Road and the other available property, which is also a light blue), we can maximize the rent potential significantly.
#
# **3. Rent with Development:**
# Once developed with four houses, the rent skyrockets to $600. This represents a staggering return on investment. To put this in perspective, if our player invests just $200 in houses (four houses at $50 each) on this single property, they could then collect $600 in rent from opponents landing on it. This would yield a return of 300% on that house investment, significantly enhancing our player’s cash flow and creating a formidable barrier to entry for opponents.
#
# **4. Strategic Positioning:**
# Pentonville Road is positioned among the early-game properties of the board. The light blue properties are typically landed on more frequently than many other properties due to their placement, making them lucrative for rent collection. By acquiring Pentonville Road, our player not only adds to their property portfolio but also enhances their chances of receiving rent as opponents navigate the board.
#
# **5. Future Growth:**
# Acquiring Pentonville Road is not just about the immediate benefits—it's about future growth. The light blue properties are often undervalued in the early game but can lead to a significant advantage as the game progresses. By developing a monopoly on these properties, our player can create a stronghold that can deter opponents and secure consistent income.
#
# **6. Psychological Advantage:**
# Lastly, owning properties creates a psychological edge. Players who own properties can influence the game's dynamics, encouraging trades with other players and fostering a sense of control. The ability to negotiate and leverage properties for trades can lead to acquiring even more valuable assets, further increasing our player's position.
#
# In conclusion, purchasing Pentonville Road is not merely a decision to buy a property; it is a strategic maneuver that positions our player for both immediate gains and long-term success. With a solid cash reserve, the potential for high returns, and the opportunity to develop a significant property portfolio, this investment is a calculated step toward victory in the game of Monopoly. Thank you for your consideration.
#
#
# Laywer AGAINST Arguments: Ladies and gentlemen of the jury, esteemed members of the Monopoly board, I stand before you today to argue against the decision to purchase Pentonville Road, a property that may seem attractive at first glance but is, in fact, a strategic misstep given the current circumstances of our client.
#
# Firstly, let's examine the financial implications of this purchase. Pentonville Road costs 120, which represents a significant investment of our client's cash reserves. While our client currently has 1500 in cash, this purchase will reduce their liquidity, leaving them with only 1380. In a game where cash flow is crucial for survival and potential future investments, this reduction could hinder our client’s ability to respond to unforeseen expenses, such as landing on an opponent's developed property or paying fines.
#
# Moreover, the base rent for Pentonville Road is only 8, which is a meager return on investment. To put this into perspective, even if our client were to build houses (at a cost of 50 each), they would need to invest an additional 200 for four houses before seeing a substantial increase in rent—600 with four houses and one hotel. This means our client would have to spend a total of 320 (120 for the property and 200 for the houses) just to realize a return that is not guaranteed, especially given that they currently own no light blue properties. Without owning additional properties in this color group, the potential for increased rent from building houses is severely limited.
#
# Furthermore, the strategy of monopolizing properties is vital in Monopoly. Our client currently owns no properties. Investing in a single property like Pentonville Road does not advance their position towards creating a monopoly. Without owning the other light blue properties (which are only two in total), the likelihood of maximizing rent through development becomes slim. The absence of a strategic property grouping means that our client is likely to struggle in gaining a competitive edge against other players who may already have established monopolies, thereby putting our client at a significant disadvantage.
#
# Additionally, we must consider the opportunity costs associated with this purchase. The funds allocated to Pentonville Road could instead be used to invest in properties with higher return potential, such as those in higher rent brackets or even purchasing multiple lower-cost properties that could lead to a more diverse portfolio. These alternatives can provide better opportunities for developing a monopoly and increasing rental income.
#
# Finally, let us not forget the importance of adaptability in Monopoly. By committing to a single property, our client risks becoming stagnant in their approach. The game is dynamic, and the ability to respond to changing circumstances is crucial. By maintaining their cash reserves and seeking out better investment opportunities, our client can remain agile and ready to capitalize on potential deals or property trades that may yield greater returns.
#
# In conclusion, purchasing Pentonville Road is not a strategic decision. The limited return on investment, lack of potential for monopolization, opportunity costs, and the need for financial flexibility all suggest that our client should refrain from this purchase. Instead, they should focus on building a more robust strategy that positions them for success in the game of Monopoly. Thank you.
#
#
# Judge's Decision: **not buy**
#
# While Pentonville Road may seem like a reasonable investment due to its low cost and potential for development, the strategic drawbacks outweigh the benefits. The player currently owns no light blue properties, which significantly limits the rent potential and the likelihood of creating a monopoly. Additionally, the initial investment and subsequent development costs could deplete cash reserves, leaving the player vulnerable to unforeseen expenses or opportunities. Instead, the player should focus on maintaining liquidity and seeking properties that offer better returns or a chance to establish a more robust portfolio. This strategy would better position the player for success in the dynamic environment of Monopoly.
